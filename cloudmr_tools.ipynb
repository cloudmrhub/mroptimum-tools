# %% [markdown]
# <a href="https://colab.research.google.com/github/cloudmrhub/mroptimum-tools/blob/main/cloudmr_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cloudmr Tools — Notebook Guide
#
# > **Purpose**: This notebook demonstrates how to install **cloudmr-tools**, load example MRI k‑space/noise data, and run common 2D reconstructions (RSS, B1, SENSE, GRAPPA).
#
#
# ## Repro/Environment
#
# - Python ≥ 3.9 recommended

# %%
# !pip install git+https://github.com/cloudmrhub/cloudmr-tools
# Out:
# Collecting git+https://github.com/cloudmrhub/cloudmr-tools
#   Cloning https://github.com/cloudmrhub/cloudmr-tools to /tmp/pip-req-build-0hs6tssj
#   Running command git clone --filter=blob:none --quiet https://github.com/cloudmrhub/cloudmr-tools /tmp/pip-req-build-0hs6tssj
#   Resolved https://github.com/cloudmrhub/cloudmr-tools to commit 86f2a44f7c8a19eaa1a380a30ba0798df4411e33
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git (from cmtools==2.2.3.6)
#   Cloning https://github.com/erosmontin/pyable.git to /tmp/pip-install-swl7lp75/pyable-eros-montin_4e6871023bec4d5586e4088623411ad9
#   Running command git clone --filter=blob:none --quiet https://github.com/erosmontin/pyable.git /tmp/pip-install-swl7lp75/pyable-eros-montin_4e6871023bec4d5586e4088623411ad9
#   Resolved https://github.com/erosmontin/pyable.git to commit 4cd2b95f5352c165a1a59c187033f1eb6cec00f4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pynico-eros-montin@ git+https://github.com/erosmontin/pynico.git (from cmtools==2.2.3.6)
#   Cloning https://github.com/erosmontin/pynico.git to /tmp/pip-install-swl7lp75/pynico-eros-montin_c28279e3f3ee484d8d1eb90dba79e6ba
#   Running command git clone --filter=blob:none --quiet https://github.com/erosmontin/pynico.git /tmp/pip-install-swl7lp75/pynico-eros-montin_c28279e3f3ee484d8d1eb90dba79e6ba
#   Resolved https://github.com/erosmontin/pynico.git to commit 9efe33a85c0a092e3fea6603fead70df08d7af7d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting raider-eros-montin@ git+https://github.com/erosmontin/raider.git (from cmtools==2.2.3.6)
#   Cloning https://github.com/erosmontin/raider.git to /tmp/pip-install-swl7lp75/raider-eros-montin_abbb988da40c45f18bf5cc7665bd87e4
#   Running command git clone --filter=blob:none --quiet https://github.com/erosmontin/raider.git /tmp/pip-install-swl7lp75/raider-eros-montin_abbb988da40c45f18bf5cc7665bd87e4
#   Resolved https://github.com/erosmontin/raider.git to commit 4fe81b87fdcddd20ea90db6ea3a1425b9872b1a6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting boto3 (from cmtools==2.2.3.6)
#   Downloading boto3-1.42.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from cmtools==2.2.3.6) (3.10.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from cmtools==2.2.3.6) (11.3.0)
# Collecting pygrappa (from cmtools==2.2.3.6)
#   Downloading pygrappa-0.26.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from cmtools==2.2.3.6) (2.32.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cmtools==2.2.3.6) (1.16.3)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.12/dist-packages (from cmtools==2.2.3.6) (8.2.3)
# Collecting sphinx-rtd-theme (from cmtools==2.2.3.6)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting botocore<1.42.0,>=1.41.6 (from boto3->cmtools==2.2.3.6)
#   Downloading botocore-1.41.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->cmtools==2.2.3.6)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3->cmtools==2.2.3.6)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cmtools==2.2.3.6) (2.9.0.post0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6) (0.25.2)
# Collecting simpleitk>2.0 (from pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6)
#   Downloading simpleitk-2.5.3-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.4 kB)
# Collecting vtk (from pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6)
#   Downloading vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pynico-eros-montin@ git+https://github.com/erosmontin/pynico.git->cmtools==2.2.3.6) (75.2.0)
# Collecting ismrmrd-python-tools@ git+https://github.com/ismrmrd/ismrmrd-python-tools.git (from raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6)
#   Cloning https://github.com/ismrmrd/ismrmrd-python-tools.git to /tmp/pip-install-swl7lp75/ismrmrd-python-tools_c0eeb9b5fffd4247ba81795d0a64019a
#   Running command git clone --filter=blob:none --quiet https://github.com/ismrmrd/ismrmrd-python-tools.git /tmp/pip-install-swl7lp75/ismrmrd-python-tools_c0eeb9b5fffd4247ba81795d0a64019a
#   Resolved https://github.com/ismrmrd/ismrmrd-python-tools.git to commit 17fe6fbf1bb645112e2ad0023eb4f42afb36421e
#   Preparing metadata (setup.py) ... done
# Collecting twixtools@ git+https://github.com/pehses/twixtools.git (from raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6)
#   Cloning https://github.com/pehses/twixtools.git to /tmp/pip-install-swl7lp75/twixtools_93dfbd5ca0f545f1ba9dbcfbeb842312
#   Running command git clone --filter=blob:none --quiet https://github.com/pehses/twixtools.git /tmp/pip-install-swl7lp75/twixtools_93dfbd5ca0f545f1ba9dbcfbeb842312
#   Resolved https://github.com/pehses/twixtools.git to commit 214207cef1d7c7bc5ca83e81a5e7faaad45ab3de
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ismrmrd (from raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6)
#   Downloading ismrmrd-1.14.2-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->cmtools==2.2.3.6) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->cmtools==2.2.3.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->cmtools==2.2.3.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->cmtools==2.2.3.6) (2025.11.12)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.19.2)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx->cmtools==2.2.3.6) (3.1.0)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->cmtools==2.2.3.6)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx->cmtools==2.2.3.6) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->cmtools==2.2.3.6) (1.17.0)
# Requirement already satisfied: h5py>=2.3 in /usr/local/lib/python3.12/dist-packages (from ismrmrd->raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6) (3.15.1)
# Collecting xsdata>=22.12 (from ismrmrd->raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6)
#   Downloading xsdata-25.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6) (3.6)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pyable-eros-montin@ git+https://github.com/erosmontin/pyable.git->cmtools==2.2.3.6) (0.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from twixtools@ git+https://github.com/pehses/twixtools.git->raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from xsdata>=22.12->ismrmrd->raider-eros-montin@ git+https://github.com/erosmontin/raider.git->cmtools==2.2.3.6) (4.15.0)
# Downloading boto3-1.42.0-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 3.6 MB/s eta 0:00:00
# Downloading pygrappa-0.26.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.4/541.4 kB 16.5 MB/s eta 0:00:00
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 64.8 MB/s eta 0:00:00
# Downloading botocore-1.41.6-py3-none-any.whl (14.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 69.4 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00
# Downloading simpleitk-2.5.3-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (52.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 11.7 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 7.7 MB/s eta 0:00:00
# Downloading ismrmrd-1.14.2-py3-none-any.whl (32 kB)
# Downloading vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 MB 7.6 MB/s eta 0:00:00
# Downloading xsdata-25.7-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.5/234.5 kB 10.4 MB/s eta 0:00:00
# Building wheels for collected packages: cmtools, pyable-eros-montin, pynico-eros-montin, raider-eros-montin, ismrmrd-python-tools, twixtools
#   Building wheel for cmtools (pyproject.toml) ... done
#   Created wheel for cmtools: filename=cmtools-2.2.3.6-py3-none-any.whl size=2714057 sha256=5dc308f03b7d4350770c0982e561990c41d593c4ce1e4447b32d6e0a1f38931e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f0wiwfae/wheels/24/95/95/e2808e87634b7c84a7d06628df604ed061bc5ddfe08eb391a4
#   Building wheel for pyable-eros-montin (pyproject.toml) ... done
#   Created wheel for pyable-eros-montin: filename=pyable_eros_montin-0.2.2-py3-none-any.whl size=23432 sha256=7fd8adf28248238fcb94fc6bf184f10f63b550e7535addc10dd59db5b04f27d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f0wiwfae/wheels/3e/cf/45/4bcc25a8ea221120220549cead91e2b87e1365248f91288468
#   Building wheel for pynico-eros-montin (pyproject.toml) ... done
#   Created wheel for pynico-eros-montin: filename=pynico_eros_montin-0.2.3.2-py3-none-any.whl size=8775 sha256=656af81f37b88c1c6ac5dc650f02fdfe9c8c30b88ebd629711c08d66bbe59dca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f0wiwfae/wheels/04/63/e0/703c44768e8105a7cd0f85eb0e3a842dfc10cd27de894cab86
#   Building wheel for raider-eros-montin (pyproject.toml) ... done
#   Created wheel for raider-eros-montin: filename=raider_eros_montin-0.1.5-py3-none-any.whl size=4961 sha256=bdeeac7bda8740a30693d907de8b98c85f9d6987b9c0cc097f81db7242240332
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f0wiwfae/wheels/cd/c3/62/59c150130e63d47f82ee713b958a7ed5e6f0f910e1a17c915b
#   Building wheel for ismrmrd-python-tools (setup.py) ... done
#   Created wheel for ismrmrd-python-tools: filename=ismrmrd_python_tools-0.3-py3-none-any.whl size=16869 sha256=90e2a09a5f36405f576447c505def7d03f1f344ebe463b9cad5b0c635a2be601
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f0wiwfae/wheels/e9/88/b2/125cc6da78c7f91d0946851f359d9e6ce6f0a74de1b7f66661
#   Building wheel for twixtools (pyproject.toml) ... done
#   Created wheel for twixtools: filename=twixtools-0.24-py3-none-any.whl size=43180 sha256=5e3eca7f6d35e709e7c0ef2e29209c21319601812ec8b874cdbda7a5737bc5bb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f0wiwfae/wheels/80/1d/4b/e07711da69af612067762695b788de2d2358227df76ec97696
# Successfully built cmtools pyable-eros-montin pynico-eros-montin raider-eros-montin ismrmrd-python-tools twixtools
# Installing collected packages: simpleitk, ismrmrd-python-tools, xsdata, pynico-eros-montin, pygrappa, jmespath, ismrmrd, botocore, vtk, twixtools, sphinxcontrib-jquery, s3transfer, sphinx-rtd-theme, raider-eros-montin, pyable-eros-montin, boto3, cmtools
# Successfully installed boto3-1.42.0 botocore-1.41.6 cmtools-2.2.3.6 ismrmrd-1.14.2 ismrmrd-python-tools-0.3 jmespath-1.0.1 pyable-eros-montin-0.2.2 pygrappa-0.26.3 pynico-eros-montin-0.2.3.2 raider-eros-montin-0.1.5 s3transfer-0.16.0 simpleitk-2.5.3 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1 twixtools-0.24 vtk-9.5.2 xsdata-25.7

# %%
# Load the data available for testing
from pynico_eros_montin import pynico as pn

import numpy as np
import matplotlib.pyplot as plt

import cmtools
import os
import importlib.util
import warnings
warnings.filterwarnings("ignore")
# get the data
spec = importlib.util.find_spec('cmtools')
print(spec.submodule_search_locations)
if spec is not None:
    package_path = spec.submodule_search_locations[0]
    package_path=os.path.join(package_path,'testdata.pkl')
else:
    print("cmtools module not found")

a=pn.Pathable(package_path)
A=a.readPkl()
S=A[0]["signal"]
N=A[0]["noise"]

import matplotlib.pyplot as plt
plt.figure()
plt.subplot(121)
plt.imshow(np.abs(S[:,:,0]))
plt.title('Signal K-space First Coil')
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.ylabel('Frequency Encoding')
plt.xlabel('Phase Encoding')
plt.subplot(122)

plt.imshow(np.abs(N[:,:,0]))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.title('Noise K-space First Coil')
plt.ylabel('Frequency Encoding')
plt.xlabel('Phase Encoding')
# Out:
# ['/usr/local/lib/python3.12/dist-packages/cmtools']
# Text(0.5, 0, 'Phase Encoding')

# %% [markdown]
# # Root Sum of Squares Reconstruction

# %%
from cmtools.cm2D import cm2DReconRSS

L=cm2DReconRSS()
L.setNoiseKSpace(N)
L.setSignalKSpace(S)
OUT=L.getOutput()

#plotting
plt.figure()
plt.imshow(np.abs(OUT))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.ylabel('Frequency Encoding')
plt.xlabel('Phase Encoding')
plt.tight_layout()
plt.title('RSS recon')
# Out:
# Text(0.5, 1.0, 'RSS recon')

# %% [markdown]
# # Noise Covariance and prewhitening

# %%
from logging import warning
from cmtools.cm2D import cm2DReconRSS, cm2DReconB1,cm2DReconSENSE,cm2DGFactorSENSE,cm2DReconGRAPPA
import cmtools.cm as cm

L=cm2DReconRSS()
L.setSignalKSpace(S)
L.setNoiseKSpace(N)

NBW=L.getNoiseBandWidth()

NC=L.getNoiseCovariance()
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(np.abs(NC))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

plt.title(f'Noise Covariance Matrix BW:{NBW:.3f}')

plt.subplot(122)
plt.imshow(np.abs(L.getNoiseCovarianceCoefficients()))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

plt.title(f'Noise Coefficient Matrix BW:{NBW:.3f}')


p=L.getPrewhitenedSignal()
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(np.abs(p[:,:,0]))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

plt.title('Prewhitened K-space First Coil')

plt.subplot(122)
plt.imshow(np.abs(S[:,:,0]))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.title('Original K-space First Coil')
# Out:
# Text(0.5, 1.0, 'Original K-space First Coil')

# %% [markdown]
# # Coil Sensitivity Maps

# %%
L=cm2DReconB1()
L.setSignalKSpace(S)
L.setNoiseKSpace(N)
L.setReferenceKSpace(S)
L.prepareCoilSensitivityMatrixPlot(title='B1 Coil Sensitivity Maps')
plt.figure()
plt.imshow(np.abs(L.getOutput()))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.title('B1 Reconstruction')
# Out:
# calculateCoilsSensitivityMask2D reference
# Text(0.5, 1.0, 'B1 Reconstruction')

# %% [markdown]
# # SENSE Accelerations

# %%
# Acceleration frequency and phase
FA=1
PA=2
# Sutocalibration lines
ACL=24
L=cm2DReconSENSE()
L.setAcceleration([FA,PA])
US,REF=cm.mimicAcceleration2D(S,[FA,PA],ACL=[np.nan,ACL])

L.setSignalKSpace(US)
L.setNoiseKSpace(N)
L.setReferenceKSpace(REF)
L.setAutocalibrationLines(ACL)

plt.figure(figsize=(10,10))
plt.subplot(221)
plt.imshow(np.abs(L.getOutput()))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.title('SENSE Reconstruction')
plt.colorbar()



L.__class__=cm2DGFactorSENSE
plt.subplot(222)
G=L.getOutput()
plt.imshow(np.abs(G),vmin=0,vmax=2)
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.colorbar()
plt.title('G Factor')

iG=1.0/G
iG[np.isnan(iG)]=0
plt.subplot(223)
plt.imshow(iG)
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.colorbar()
plt.title('Inverse G Factor')


A=L.outputMask.get()
print(A.shape)
plt.subplot(224)
plt.imshow(A[:,:,0])
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.colorbar()
plt.title('Mask')
# Out:
# calculateCoilsSensitivityMask2D reference
# (96, 96, 16)
# Text(0.5, 1.0, 'Mask')

# %% [markdown]
# # Acceleration GRAPPA

# %%
FA=1
PA=3
ACLF=24
ACLP=24
GK=[4,5]

US,REF=cm.mimicAcceleration2D(S,[FA,PA],[ACLF,ACLP])
L=cm2DReconGRAPPA()
L.setSignalKSpace(US)
L.setAcceleration([FA,PA])
L.setAutocalibrationLines([ACLF,ACLP])
L.setNoiseKSpace(N)
L.setGRAPPAKernel(GK)
L.setReferenceKSpace(REF)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(np.abs(L.getOutput()))
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

plt.title('GRAPPA Reconstructin')

plt.subplot(122)
plt.imshow(np.abs(US[:,:,0]))
plt.title('Undersampled K-space Signal First Coil')
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
plt.show()
